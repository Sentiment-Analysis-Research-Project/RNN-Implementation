# %% [markdown]
# ## Only Once
# This part is to be done only once and for further variations directly use the pre-trained saved file (as the dataset is same)

# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import nltk
import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import string
import re #regular expression
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import numpy as np
import os
import tensorflow as tf
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ### Read and see the dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Sentiment Analysis - Research Project/Dataset IMDB/IMDB Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### Convert sentiment column:
# - `positive = 1`
# - `negative = 0`

# %%
df['sentiment'][df['sentiment']=='positive'] = 1
df['sentiment'][df['sentiment']=='negative'] = 0
df.shape
# Out:
# (50000, 2)

# %% [markdown]
# ### Preprocessing
# output will be a list of {list of words for each sentence}.

# %%
lemmatizer = WordNetLemmatizer()
reviews = list()
stop_words = set(stopwords.words('english'))
lines = df['review'].values.tolist()

for line in lines:
    
    #first we remove the tags as once we split them to words its hard to remove them
    line = re.sub(r'<[^>]+>',' ',line) #remove html tags
    
    tokens = word_tokenize(line)
    tokens = [w.lower() for w in tokens]
    
    #remove punctuaution
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]

    #remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]

    #filter out stop words
    words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words and len(w)>2]
    reviews.append(words)

# %% [markdown]
# ### Convert to Word2Vec

# %%
EMBED_DIM = 100 #each word will become a vector of 100 dimensions
sum_len = 0
max_len = 0
for s in reviews:
    sum_len = sum_len + len(s)
    max_len = max(len(s),max_len)

avg_len = int(sum_len/len(reviews))
print(f'summation - {sum_len}, maximum - {max_len}, average - {avg_len}')
# Out:
# summation - 5767285, maximum - 1383, average - 115

# %% [markdown]
# ## Variations : Start here and use pre-trained file

# %%
embeddings_index = {}
f = open('/content/drive/MyDrive/Sentiment Analysis - Research Project/Dataset IMDB/imdb_embedding_word2vec.txt',encoding='utf-8')
for line in f:
    values = line.split()
    if(len(values)==2): #for skipping the first value of doc size
        continue
    word = values[0]
    coefs = np.asarray(values[1:])
    embeddings_index[word] = coefs
f.close()
print(f'loaded {len(embeddings_index)} word vectors')
# Out:
# loaded 124186 word vectors

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU, Bidirectional, SimpleRNN
from keras.layers.embeddings import Embedding

# %%
#vectorize the text samples into 2D integer tensor
tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(reviews)
sequences = tokenizer_obj.texts_to_sequences(reviews)

# fit_on_texts Updates internal vocabulary based on a list of texts. 
# This method creates the vocabulary index based on word frequency.
# So if you give it something like, "The cat sat on the mat." 
# It will create a dictionary s.t. word_index["the"] = 1; 
# word_index["cat"] = 2 it is word -> index dictionary so every word gets a unique integer value.
# 0 is reserved for padding. So lower integer means more frequent word (often the first few are stop words because they appear a lot).

# texts_to_sequences Transforms each text in texts to a sequence of integers.
# So it basically takes each word in the text and replaces it with its corresponding integer value from the word_index dictionary. 
# Nothing more, nothing less, certainly no magic involved.

#pad sequences
word_index = tokenizer_obj.word_index
print(f'Found {len(word_index)} unique tokens.')


review_pad = pad_sequences(sequences, maxlen=max_len,padding='post')
sentiment = df['sentiment'].values
print(f'Shape of review tensor: {review_pad.shape} and type - {type(review_pad)}')
print(f'Shape of sentiment tensor: {sentiment.shape} and type - {type(sentiment)}')
# Out:
# Found 124186 unique tokens.
# Shape of review tensor: (50000, 1383) and type - <class 'numpy.ndarray'>
# Shape of sentiment tensor: (50000,) and type - <class 'numpy.ndarray'>

# %%
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, EMBED_DIM))

for word, i in word_index.items():
    # if i>num_words:
    #     continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
VALIDATION_SPLIT = 0.3 #70-30 train test split
indices = np.arange(review_pad.shape[0])

np.random.shuffle(indices)
review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int(VALIDATION_SPLIT * review_pad.shape[0])

X_train_pad = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

# %%
print(f'Shape of X_train_pad tensor: {X_train_pad.shape}')
print(f'Shape of y_train tensor: {y_train.shape}')
print(f'Shape of X_test_pad tensor: {X_test_pad.shape}')
print(f'Shape of y_test tensor: {y_test.shape}')
# Out:
# Shape of X_train_pad tensor: (35000, 1383)
# Shape of y_train tensor: (35000,)
# Shape of X_test_pad tensor: (15000, 1383)
# Shape of y_test tensor: (15000,)

# %%
# data = [[1,2,3],[4,5,6]]
# data_np = np.asarray(data, np.float32)

# data_tf = tf.convert_to_tensor(data_np, np.float32)

y_train = np.asarray(y_train,dtype=np.int)
y_test = np.asarray(y_test,dtype=np.int)
# y_test = tf.convert_to_tensor(y_test,np.float32)
# y_train = tf.convert_to_tensor(y_train,np.float32)

# %%
#define model
model = Sequential()
embedding_layer = Embedding(num_words,EMBED_DIM,weights=[embedding_matrix],input_length=max_len,trainable=False)
model.add(embedding_layer)
model.add(Bidirectional(LSTM(64,dropout=0.2,return_sequences=True)))
model.add(LSTM(64))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1383, 100)         12418700
# _________________________________________________________________
# bidirectional (Bidirectional (None, 1383, 128)         84480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 12,552,653
# Trainable params: 133,953
# Non-trainable params: 12,418,700
# _________________________________________________________________

# %%
print('Train....')
history = model.fit(X_train_pad, y_train, batch_size=128, epochs=30, validation_data=(X_test_pad,y_test),verbose=1)
# Out:
# Train....
# Epoch 1/30
# 274/274 [==============================] - 173s 596ms/step - loss: 0.6933 - accuracy: 0.4965 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 2/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6933 - val_accuracy: 0.4965
# Epoch 3/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 4/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.5011 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 5/30
# 274/274 [==============================] - 164s 597ms/step - loss: 0.6932 - accuracy: 0.4977 - val_loss: 0.6933 - val_accuracy: 0.4965
# Epoch 6/30
# 274/274 [==============================] - 163s 596ms/step - loss: 0.6932 - accuracy: 0.5015 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 7/30
# 274/274 [==============================] - 163s 596ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 8/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6932 - accuracy: 0.5011 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 9/30
# 274/274 [==============================] - 163s 596ms/step - loss: 0.6931 - accuracy: 0.5007 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 10/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6931 - accuracy: 0.5022 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 11/30
# 274/274 [==============================] - 163s 593ms/step - loss: 0.6932 - accuracy: 0.4983 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 12/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6933 - val_accuracy: 0.4965
# Epoch 13/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 14/30
# 274/274 [==============================] - 163s 595ms/step - loss: 0.6932 - accuracy: 0.4986 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 15/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6931 - val_accuracy: 0.4965
# Epoch 16/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.4996 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 17/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 18/30
# 274/274 [==============================] - 163s 593ms/step - loss: 0.6932 - accuracy: 0.4977 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 19/30
# 274/274 [==============================] - 163s 594ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 20/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6932 - accuracy: 0.4979 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 21/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6931 - accuracy: 0.5015 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 22/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6931 - accuracy: 0.5003 - val_loss: 0.6934 - val_accuracy: 0.4965
# Epoch 23/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6932 - accuracy: 0.4985 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 24/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6931 - accuracy: 0.4999 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 25/30
# 274/274 [==============================] - 163s 595ms/step - loss: 0.6931 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 26/30
# 274/274 [==============================] - 163s 593ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 27/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6931 - accuracy: 0.4998 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 28/30
# 274/274 [==============================] - 162s 593ms/step - loss: 0.6931 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4965
# Epoch 29/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6931 - accuracy: 0.4992 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 30/30
# 274/274 [==============================] - 162s 592ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6931 - val_accuracy: 0.5035

# %%
def plotLearningCurve(history,epochs):
    import matplotlib.pyplot as plt

    epoch_range = range(1,epochs+1)
    plt.plot(epoch_range,history['accuracy'])
    plt.plot(epoch_range,history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(['Train','Val'])
    plt.show()

    plt.plot(epoch_range,history['loss'])
    plt.plot(epoch_range,history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train','Val'])
    plt.show()

# %%
plotLearningCurve(history.history,len(history.epoch))

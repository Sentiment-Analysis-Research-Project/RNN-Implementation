# %% [markdown]
# ## Only Once
# This part is to be done only once and for further variations directly use the pre-trained saved file (as the dataset is same)

# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import nltk
import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import string
import re #regular expression
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import numpy as np
import os
import tensorflow as tf
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ### Read and see the dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Sentiment Analysis - Playground/Dataset IMDB/IMDB Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### Convert sentiment column:
# - `positive = 1`
# - `negative = 0`

# %%
df['sentiment'][df['sentiment']=='positive'] = 1
df['sentiment'][df['sentiment']=='negative'] = 0
df.shape
# Out:
# (50000, 2)

# %% [markdown]
# ### Preprocessing
# output will be a list of {list of words for each sentence}.

# %%
lemmatizer = WordNetLemmatizer()
reviews = list()
stop_words = set(stopwords.words('english'))
lines = df['review'].values.tolist()

for line in lines:
    
    #first we remove the tags as once we split them to words its hard to remove them
    line = re.sub(r'<[^>]+>',' ',line) #remove html tags
    
    tokens = word_tokenize(line)
    tokens = [w.lower() for w in tokens]
    
    #remove punctuaution
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]

    #remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]

    #filter out stop words
    words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words and len(w)>2]
    reviews.append(words)

# %% [markdown]
# ### Convert to Word2Vec

# %%
EMBED_DIM = 100 #each word will become a vector of 100 dimensions
sum_len = 0
max_len = 0
for s in reviews:
    sum_len = sum_len + len(s)
    max_len = max(len(s),max_len)

avg_len = int(sum_len/len(reviews))
print(f'summation - {sum_len}, maximum - {max_len}, average - {avg_len}')
# Out:
# summation - 5767285, maximum - 1383, average - 115

# %% [markdown]
# ## Variations : Start here and use pre-trained file

# %%
embeddings_index = {}
f = open('/content/drive/MyDrive/Sentiment Analysis - Playground/Dataset IMDB/imdb_embedding_word2vec.txt',encoding='utf-8')
for line in f:
    values = line.split()
    if(len(values)==2): #for skipping the first value of doc size
        continue
    word = values[0]
    coefs = np.asarray(values[1:])
    embeddings_index[word] = coefs
f.close()
print(f'loaded {len(embeddings_index)} word vectors')
# Out:
# loaded 124186 word vectors

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU, Bidirectional, SimpleRNN
from keras.layers.embeddings import Embedding

# %%
#vectorize the text samples into 2D integer tensor
tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(reviews)
sequences = tokenizer_obj.texts_to_sequences(reviews)

# fit_on_texts Updates internal vocabulary based on a list of texts. 
# This method creates the vocabulary index based on word frequency.
# So if you give it something like, "The cat sat on the mat." 
# It will create a dictionary s.t. word_index["the"] = 1; 
# word_index["cat"] = 2 it is word -> index dictionary so every word gets a unique integer value.
# 0 is reserved for padding. So lower integer means more frequent word (often the first few are stop words because they appear a lot).

# texts_to_sequences Transforms each text in texts to a sequence of integers.
# So it basically takes each word in the text and replaces it with its corresponding integer value from the word_index dictionary. 
# Nothing more, nothing less, certainly no magic involved.

#pad sequences
word_index = tokenizer_obj.word_index
print(f'Found {len(word_index)} unique tokens.')


review_pad = pad_sequences(sequences, maxlen=max_len,padding='post')
sentiment = df['sentiment'].values
print(f'Shape of review tensor: {review_pad.shape} and type - {type(review_pad)}')
print(f'Shape of sentiment tensor: {sentiment.shape} and type - {type(sentiment)}')
# Out:
# Found 124186 unique tokens.
# Shape of review tensor: (50000, 1383) and type - <class 'numpy.ndarray'>
# Shape of sentiment tensor: (50000,) and type - <class 'numpy.ndarray'>

# %%
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, EMBED_DIM))

for word, i in word_index.items():
    # if i>num_words:
    #     continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
VALIDATION_SPLIT = 0.3 #70-30 train test split
indices = np.arange(review_pad.shape[0])

np.random.shuffle(indices)
review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int(VALIDATION_SPLIT * review_pad.shape[0])

X_train_pad = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

# %%
print(f'Shape of X_train_pad tensor: {X_train_pad.shape}')
print(f'Shape of y_train tensor: {y_train.shape}')
print(f'Shape of X_test_pad tensor: {X_test_pad.shape}')
print(f'Shape of y_test tensor: {y_test.shape}')
# Out:
# Shape of X_train_pad tensor: (35000, 1383)
# Shape of y_train tensor: (35000,)
# Shape of X_test_pad tensor: (15000, 1383)
# Shape of y_test tensor: (15000,)

# %%
# data = [[1,2,3],[4,5,6]]
# data_np = np.asarray(data, np.float32)

# data_tf = tf.convert_to_tensor(data_np, np.float32)

y_train = np.asarray(y_train,dtype=np.int)
y_test = np.asarray(y_test,dtype=np.int)
# y_test = tf.convert_to_tensor(y_test,np.float32)
# y_train = tf.convert_to_tensor(y_train,np.float32)

# %%
#define model
model = Sequential()
embedding_layer = Embedding(num_words,EMBED_DIM,weights=[embedding_matrix],input_length=max_len,trainable=False)
model.add(embedding_layer)
model.add(Bidirectional(LSTM(64,dropout=0.2)))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1383, 100)         12418700
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 12,503,309
# Trainable params: 84,609
# Non-trainable params: 12,418,700
# _________________________________________________________________

# %%
print('Train....')
history = model.fit(X_train_pad, y_train, batch_size=128, epochs=30, validation_data=(X_test_pad,y_test),verbose=1)
# Out:
# Train....
# Epoch 1/30
# 274/274 [==============================] - 109s 397ms/step - loss: 0.4478 - accuracy: 0.7958 - val_loss: 0.3702 - val_accuracy: 0.8391
# Epoch 2/30
# 274/274 [==============================] - 108s 395ms/step - loss: 0.3774 - accuracy: 0.8360 - val_loss: 0.3292 - val_accuracy: 0.8656
# Epoch 3/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.3280 - accuracy: 0.8612 - val_loss: 0.3199 - val_accuracy: 0.8719
# Epoch 4/30
# 274/274 [==============================] - 108s 395ms/step - loss: 0.3103 - accuracy: 0.8700 - val_loss: 0.2907 - val_accuracy: 0.8813
# Epoch 5/30
# 274/274 [==============================] - 107s 391ms/step - loss: 0.3009 - accuracy: 0.8730 - val_loss: 0.2942 - val_accuracy: 0.8773
# Epoch 6/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2898 - accuracy: 0.8788 - val_loss: 0.2823 - val_accuracy: 0.8838
# Epoch 7/30
# 274/274 [==============================] - 108s 395ms/step - loss: 0.2820 - accuracy: 0.8806 - val_loss: 0.2700 - val_accuracy: 0.8893
# Epoch 8/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2724 - accuracy: 0.8859 - val_loss: 0.2655 - val_accuracy: 0.8915
# Epoch 9/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2670 - accuracy: 0.8871 - val_loss: 0.2789 - val_accuracy: 0.8823
# Epoch 10/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.2594 - accuracy: 0.8916 - val_loss: 0.2600 - val_accuracy: 0.8917
# Epoch 11/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2532 - accuracy: 0.8936 - val_loss: 0.2664 - val_accuracy: 0.8928
# Epoch 12/30
# 274/274 [==============================] - 107s 391ms/step - loss: 0.2468 - accuracy: 0.8977 - val_loss: 0.2566 - val_accuracy: 0.8962
# Epoch 13/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2406 - accuracy: 0.9013 - val_loss: 0.2534 - val_accuracy: 0.8982
# Epoch 14/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2337 - accuracy: 0.9032 - val_loss: 0.2540 - val_accuracy: 0.8972
# Epoch 15/30
# 274/274 [==============================] - 107s 391ms/step - loss: 0.2272 - accuracy: 0.9057 - val_loss: 0.2537 - val_accuracy: 0.8979
# Epoch 16/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2226 - accuracy: 0.9088 - val_loss: 0.2543 - val_accuracy: 0.8967
# Epoch 17/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2153 - accuracy: 0.9119 - val_loss: 0.2628 - val_accuracy: 0.8979
# Epoch 18/30
# 274/274 [==============================] - 108s 393ms/step - loss: 0.2110 - accuracy: 0.9135 - val_loss: 0.2587 - val_accuracy: 0.8981
# Epoch 19/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.2052 - accuracy: 0.9161 - val_loss: 0.2612 - val_accuracy: 0.8949
# Epoch 20/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.1973 - accuracy: 0.9197 - val_loss: 0.2608 - val_accuracy: 0.8961
# Epoch 21/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.1926 - accuracy: 0.9210 - val_loss: 0.2717 - val_accuracy: 0.8911
# Epoch 22/30
# 274/274 [==============================] - 107s 391ms/step - loss: 0.1871 - accuracy: 0.9237 - val_loss: 0.2713 - val_accuracy: 0.8950
# Epoch 23/30
# 274/274 [==============================] - 107s 390ms/step - loss: 0.1839 - accuracy: 0.9254 - val_loss: 0.2676 - val_accuracy: 0.8969
# Epoch 24/30
# 274/274 [==============================] - 107s 392ms/step - loss: 0.1801 - accuracy: 0.9261 - val_loss: 0.2743 - val_accuracy: 0.8911
# Epoch 25/30
# 274/274 [==============================] - 106s 388ms/step - loss: 0.1733 - accuracy: 0.9298 - val_loss: 0.2842 - val_accuracy: 0.8927
# Epoch 26/30
# 274/274 [==============================] - 107s 389ms/step - loss: 0.1707 - accuracy: 0.9303 - val_loss: 0.2794 - val_accuracy: 0.8906
# Epoch 27/30
# 274/274 [==============================] - 107s 391ms/step - loss: 0.1665 - accuracy: 0.9350 - val_loss: 0.2756 - val_accuracy: 0.8897
# Epoch 28/30
# 274/274 [==============================] - 108s 394ms/step - loss: 0.1626 - accuracy: 0.9359 - val_loss: 0.2808 - val_accuracy: 0.8923
# Epoch 29/30
# 274/274 [==============================] - 108s 394ms/step - loss: 0.1583 - accuracy: 0.9361 - val_loss: 0.2936 - val_accuracy: 0.8921
# Epoch 30/30
# 274/274 [==============================] - 108s 394ms/step - loss: 0.1557 - accuracy: 0.9361 - val_loss: 0.2862 - val_accuracy: 0.8910

# %%
def plotLearningCurve(history,epochs):
    import matplotlib.pyplot as plt

    epoch_range = range(1,epochs+1)
    plt.plot(epoch_range,history['accuracy'])
    plt.plot(epoch_range,history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(['Train','Val'])
    plt.show()

    plt.plot(epoch_range,history['loss'])
    plt.plot(epoch_range,history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Train','Val'])
    plt.show()

# %%
plotLearningCurve(history.history,len(history.epoch))
